# %% [markdown]
# ## heading ##

# %%
###heading###

# %%
#### heading ####

# %%
## Heading ##

# %% [markdown]
# #### Heading ####

# %%
a=4
b=5
a+b
# Out:
# 9

# %%
true=4
false=6
true+false
# Out:
# 10

# %%
True=4
# Out:
#   Cell In[30], line 1
#     True=4
#     ^
# SyntaxError: cannot assign to True

# %%
True=4
False=6
True+False
# Out:
#   Cell In[31], line 1
#     True=4
#     ^
# SyntaxError: cannot assign to True

# %%
import keyword#
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(2+4)
# Out:
# 6

# %%
print(2+4+5)
p
# Out:
# 11
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 print(2+4+5)
# ----> 2 p
#
# NameError: name 'p' is not defined

# %%
p=2+4+5
p
# Out:
# 11

# %%
p=2+8+9\
+10+19
p
# Out:
# 48

# %%
a=4;b=6;c=a+b
p
# Out:
# 48

# %%
a=4,b=10
p
# Out:
#   Cell In[39], line 1
#     a=4,b=10
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a=4,b=10,c=a+b
p
# Out:
#   Cell In[40], line 1
#     a=4,b=10,c=a+b
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a,b=10,20

# %%
a+b
# Out:
# 30

# %%
a=b=5
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
5
# Out:
# 5

# %%
a,b=10,20
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
a=5
b=10
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>

# %%
i=instance(5,,int)
# Out:
#   Cell In[49], line 1
#     i=instance(5,,int)
#                  ^
# SyntaxError: invalid syntax

# %%
isinstance(5,int)
# Out:
# True

# %%
isinstance(5,str)
# Out:
# False

# %%
isinstance(str(5),str)
# Out:
# True

# %%
isinstance(True,bool)
# Out:
# True

# %%
isinstance(5,bool)
# Out:
# False

# %%
isinstance(True(5),bool)
# Out:
# <>:1: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
# C:\Users\AbdulH\AppData\Local\Temp\ipykernel_26488\4185872806.py:1: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
#   isinstance(True(5),bool)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 isinstance(True(5),bool)
#
# TypeError: 'bool' object is not callable

# %%
str="Hello World"
str[1]
# Out:
# 'e'

# %%
str[ ]
# Out:
#   Cell In[57], line 1
#     str[ ]
#          ^
# SyntaxError: invalid syntax

# %%
str[]
# Out:
#   Cell In[58], line 1
#     str[]
#         ^
# SyntaxError: invalid syntax

# %%
str[ ]
# Out:
#   Cell In[59], line 1
#     str[ ]
#          ^
# SyntaxError: invalid syntax

# %%
str[5]
# Out:
# ' '

# %%
v="Hello  India"
str[5]
# Out:
# ' '

# %%
v[5]
# Out:
# ' '

# %%
v[4]
# Out:
# 'o'

# %%
v[-1]
# Out:
# 'a'

# %%
str[-3]
# Out:
# 'r'

# %%
str[-5]
# Out:
# 'W'

# %%
str[-6]
# Out:
# ' '

# %%
str[5]
# Out:
# ' '

# %%
str[6]
# Out:
# 'W'

# %%
str[0,5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 str[0,5]
#
# TypeError: string indices must be integers, not 'tuple'

# %%
str{0,5}
# Out:
#   Cell In[71], line 1
#     str{0,5}
#        ^
# SyntaxError: invalid syntax

# %%
str[0:5]
# Out:
# 'Hello'

# %%
v[6:10]
# Out:
# ' Ind'

# %%
str[7:12]
# Out:
# 'orld'

# %%
str[6:12]
# Out:
# 'World'

# %%
str[:-5]
# Out:
# 'Hello '

# %%
str[-5:]
# Out:
# 'World'

# %%
str[1,4,5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 str[1,4,5]
#
# TypeError: string indices must be integers, not 'tuple'

# %%
str[0:0+2:0+5]
# Out:
# 'H'

# %%
str[0:5,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 str[0:5,2]
#
# TypeError: string indices must be integers, not 'tuple'

# %%
str[0:5:2]
# Out:
# 'Hlo'

# %%
str[:]
# Out:
# 'Hello World'

# %%
str[::-1]
# Out:
# 'dlroW olleH'

# %%
str[::}
# Out:
#   Cell In[84], line 1
#     str[::}
#           ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
str[::]
# Out:
# 'Hello World'

# %%
str[::1]
# Out:
# 'Hello World'

# %%
str[-1]
# Out:
# 'd'

# %%
str[1::]
# Out:
# 'ello World'

# %%
str[-1::]
# Out:
# 'd'

# %%
str[::-2]
# Out:
# 'drWolH'

# %%
str[::-1]
# Out:
# 'dlroW olleH'

# %%
str[::-3]
# Out:
# 'dooe'

# %%
replace[str,"Hello","Namaste"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 replace[str,"Hello","Namaste"]
#
# NameError: name 'replace' is not defined

# %%
str.replace["Hello","Namaste"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 str.replace["Hello","Namaste"]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
str.replace("Hello","Namaste")
# Out:
# 'Namaste World'

# %%
del str

# %%
print(str)
# Out:
# <class 'str'>

# %%
str[:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 str[:1]
#
# TypeError: type 'str' is not subscriptable

# %%
str[::]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 str[::]
#
# TypeError: type 'str' is not subscriptable

# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
x="hello"
y="world"
x+y
# Out:
# 'helloworld'

# %%
x+" "+y
# Out:
# 'hello world'

# %%
str=""Hello how are you"
p
# Out:
#   Cell In[104], line 1
#     str=""Hello how are you"
#                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str= "Hello how are you"

# %%
p
# Out:
# 48

# %%
"are" in str
# Out:
# True

# %%
"is" in str
# Out:
# False

# %%
"is" not in str
# Out:
# True

# %%
"Hello" not in str
# Out:
# False

# %%
"hello" not in str
# Out:
# True

# %%
# in and not in are membership operators #

# %%
v_greet = "Namaster how are you and how can i help you"

# %%
v_greet.partition("and")
# Out:
# ('Namaster how are you ', 'and', ' how can i help you')

# %%
v_greet.partition("Namaste")
# Out:
# ('', 'Namaste', 'r how are you and how can i help you')

# %%
v_greet.count("and")
# Out:
# 1

# %%
v_greet.count("you")
# Out:
# 2

# %%
v_greet.startswith("N")
# Out:
# True

# %%
v_greet.endswith("y")
# Out:
# False

# %%
v_greet.startswith("K")
# Out:
# False

# %%
v_greet.endswith("N")
# Out:
# False

# %%
print(upper(v_greet))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 print(upper(v_greet))
#
# NameError: name 'upper' is not defined

# %%
v_greet.upper()
# Out:
# 'NAMASTER HOW ARE YOU AND HOW CAN I HELP YOU'

# %%
print(v_greet.lower())
# Out:
# namaster how are you and how can i help you

# %%
v_new = "@abdul @hameed "
print(v_new.strip("@abd"))
# Out:
# ul @hameed

# %%
x=20
y=30
z=40
"cost of three pens {},{},{}".format(x,y,z)
# Out:
# 'cost of three pens 20,30,40'

# %%
"cost of three pens".format({x},{y},{z})
# Out:
# 'cost of three pens'

# %%
x=20
y=30
z=40
"cost of three pens".format({x},{y},{z})
# Out:
# 'cost of three pens'

# %%
x=40
y=50
z=55
"cost of three books {},{},{}".format(x,y,z)
# Out:
# 'cost of three books 40,50,55'

# %%
x=50
y=50
z=55
f"cost of three books {x},{y},{z}"
# Out:
# 'cost of three books 50,50,55'

# %%
len('hello')
# Out:
# 5

# %%
len("world")
# Out:
# 5

# %%
#Typecasting : Converting one data type to another. #
#Python is implicit type of type casting.#
''' There are 2 types of type casting 
--> Implicit -- Since we dont declare the type of variable
--> Explicit -- Since we declare the type of variable

# %%
v=5
float(v)
# Out:
# 5.0

# %%
a=23
b=25
c="Hello"
float(a)
float(a+b)
# Out:
# 48.0

# %%
a=0
bool(a)
#Anything apart from 0 will be true if you convert int to Boolean#
# Out:
# False

# %%
b=23.7
int(b)
'''Python does not rounds off the value. 
It just ignores the what is after decimal point. Here python will not convert the value to 24 unless we use any libraries'''
# Out:
# 23

# %%
b=3.5
bool(b)
# Out:
# True

# %%
f=2

type(f)
f
# Out:
# 2

# %%
x=str(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 x=str(f)
#
# TypeError: 'str' object is not callable

# %%
str(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 str(2)
#
# TypeError: 'str' object is not callable

# %%
type(str), str
# Out:
# (str, 'Hello how are you')

# %%
del str

# %%
str(1)
# Out:
# '1'

# %%
g=True
float(g)
# Out:
# 1.0

# %%
h=False
int(h)
str(h)
# Out:
# 'False'

# %%
d= "123"
type(d)
# Out:
# str

# %%
int(d)
# Out:
# 123

# %%
t=int(4)

# %%
type(t)
# Out:
# int

# %%
d="hello"
bool(d)
# Out:
# True

# %%
len("Good Morning")
# Out:
# 12
