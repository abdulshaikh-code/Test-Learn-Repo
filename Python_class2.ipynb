# %%
Greetings = "Hello everyone"
Greetings.split()
# Out:
# ['Hello', 'everyone']

# %%
g= "Hello everyone , i am abdul"
g.split()
# Out:
# ['Hello', 'everyone', ',', 'i', 'am', 'abdul']

# %%
h= "hello-everyone-i-am-abdul"
h.split("-")
# Out:
# ['hello', 'everyone', 'i', 'am', 'abdul']

# %%
r= "hello-everyone-are-you-guys-available"
r.split()
# Out:
# ['hello-everyone-are-you-guys-available']

# %%
mail='abdul.h@clinevotech.com'
mail.split('@')
# Out:
# ['abdul.h', 'clinevotech.com']

# %%
v="Namaste"
bool(v)
# Out:
# True

# %%
x=28
float(x)
# Out:
# 28.0

# %%
str(x)
# Out:
# '28'

# %%
bool(x)
# Out:
# True

# %%
b=28.7
float(b)
# Out:
# 28.7

# %%
int(b)
# Out:
# 28

# %%
bool(b)
# Out:
# True

# %%
Name=input("Enter the name")
print("My name is",Name)
# Out:
# Enter the name Abdul
# My name is Abdul

# %%
Age=int(input("Enter the age"))
print("My age is",Age)
# Out:
# Enter the age 23
# My age is 23

# %%
#Arithmatic operators#
a=30
b=10
print("Addition of a and b is",a+b)
print("Multiplication of a and b is",a*b)
print("Division of a and b is",a//b)
print("Subtraction of a and b is",a-b)
print("Mod of a and b is ",a%b)
print("Square of a is",a**2)
# Out:
# Addition of a and b is 40
# Multiplication of a and b is 300
# Division of a and b is 3
# Subtraction of a and b is 20
# Mod of a and b is  0
# Square of a is 900

# %%
#Floor value means before decimal#

# %%
#Comparision Operators#
num1=70
num2=60
num1==num2
# Out:
# False

# %%
num1!=num2
# Out:
# True

# %%
num1<num2
# Out:
# True

# %%
num1>num2
# Out:
# False

# %%
num1<=num2
# Out:
# False

# %%
#Logical Opeartors#
#AND ,OR and NOT#
number1 =10
number2 =20
if number1 == 10 and number2 == 20:
    print('True')
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
#Membership Operator IN and NOT IN#
'N' not in 'Namaste'
# Out:
# False

# %%
'Z' in 'Namaste'
# Out:
# False

# %%
#Identity Operators IS and IS NOT#
a=5
b=5
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
import sys
sys.getsizeof("hello")
# Out:
# 46

# %%
sys.getsizeof(1)
# Out:
# 28

# %%
sys.getsizeof("this is how it should be")
# Out:
# 65

# %%
#Conditional statements#
age=int(input('Enter the age'))
if age<=18:
    print('Not eligible')
else:
    print('Eligible')
# Out:
# Enter the age 19
# Eligible

# %%
height= 183
if height >= 182:
    print("You are eligible for this sport")
    print("Welcome to Sport")
else:
    print("Sorry,you are not eligible")
# Out:
# You are eligible for this sport
# Welcome to Sport

# %%
marks=int(input("How much marks you got"))
if marks >=35:
    print("pass")
else:
    print("fail")
# Out:
# How much marks you got 23
# fail
